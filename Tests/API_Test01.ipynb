# %%
#Prueba de API de Spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials



birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
    
    
    
'''
Client ID
e9b945c8f041498ba5b3295005fcd4aa

Secret ID
fc814ddc4a914af2bbf99be82159a5cd

Genius Client Access Token
na2t3YXuETlKLwHltgqRuISko1apnbOrG9WJd-gMzAmxKKbYDS-4Jmh7gAzDaN1U
'''

# %%
import lyricsgenius
api_key = "nfveFkCeKuel65FkE85p6qUqwn9yizg_r-y2ojVXTKvE6gknTnpRvdHkEqdI6qCH"
genius = lyricsgenius.Genius (api_key)
name = input("Enter Artist Name " )
artist = genius.search_artist(name)
song = input ("Type your song for Lyrics: ")
song = artist.song(song)
print(song.lyrics)
# Out:
# Enter Artist Name Mi Sobrino Memo
# Searching for songs by Mi Sobrino Memo...
#
# Song 1: "#Éramos Novios"
# Song 2: "Mi Desastre Favorito ( モカフラッペ )"
# Song 3: "Aeroplanos"
# Song 4: "Piel Canela"
# Song 5: "Cuando Fuimos Nada"
# Song 6: "Nunca Te Olvido"
# Song 7: "Te Lo Debo Contar"
# Song 8: "Somos Amigos (Solo Te Quiero para Que Juegues Conmigo)"
# Song 9: "Cuarto"
# Song 10: "Los Felices"
# Song 11: "#Pingüino Rancho"
# Song 12: "Si Te Vuelvo A Encontrar"
# Song 13: "Cuarentena"
# Song 14: "Nunca Sabrás"
# Song 15: "Viernes 13"
# Song 16: "Superhéroes & Villanos"
# Song 17: "La Casa de Café"
# Song 18: "Melphomene"
# Song 19: "Melancólico"
# Song 20: "El Queso y el Ratón"
# Song 21: "Zombie"
# Song 22: "Quizá Algún Día"
# Song 23: "Bonita y Triste"
# Done. Found 23 songs.
# Type your song for Lyrics: Zombie
# str

# %%
import pandas as pd
import csv
from pathlib import Path

path = Path("Resources/spotify_top_charts_22.csv")

spotify_df = pd.read_csv(path)

spotify_df
# Out:
#                                       uri  \
# 0    spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1    spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 2    spotify:track:3IAfUEeaXRX9s9UdKOJrFI
# 3    spotify:track:1HhNoOuqm1a5MXYEgAFl8o
# 4    spotify:track:4fouWK6XVHhzl78KzQ1UjL
# ..                                    ...
# 641  spotify:track:0So2sgVa8aJiARPl2P29u2
# 642  spotify:track:1TUuhV75FeOF6UObRsABo2
# 643  spotify:track:3GbQcjKWT7eVpUfzqwUjxv
# 644  spotify:track:7My9ca9QEIR8MvIOdIrTWA
# 645  spotify:track:4axSuOg3BqsowKjRpj59RU
#
#                                         artist_names  \
# 0                                      Glass Animals
# 1                       The Kid LAROI, Justin Bieber
# 2                                             Anitta
# 3    Imagine Dragons, JID, Arcane, League of Legends
# 4                                              GAYLE
# ..                                               ...
# 641                                            SALES
# ...

# %%
artist_list = spotify_df["artist_names"]
artist_list

names_list = spotify_df["track_name"]
names_list
# Out:
# 0                                             Heat Waves
# 1                              STAY (with Justin Bieber)
# 2                                               Envolver
# 3      Enemy (with JID) - from the series Arcane Leag...
# 4                                                abcdefu
#                              ...
# 641                                   Pope Is a Rockstar
# 642                                    Don't Think Jesus
# 643    Late To Da Party (F*CK BET) (feat. YoungBoy Ne...
# 644               From The D 2 The LBC (with Snoop Dogg)
# 645    Carolina - From The Motion Picture “Where The ...
# Name: track_name, Length: 646, dtype: object

# %%
for artist in artist_list:
    print("The artist is: " + artist)
# Out:
# The artist is: Glass Animals
# The artist is: The Kid LAROI, Justin Bieber
# The artist is: Anitta
# The artist is: Imagine Dragons, JID, Arcane, League of Legends
# The artist is: GAYLE
# The artist is: Elton John, Dua Lipa, PNAU
# The artist is: Becky G, KAROL G
# The artist is: Lil Nas X, Jack Harlow
# The artist is: Rauw Alejandro, Chencho Corleone
# The artist is: Ed Sheeran
# The artist is: Doja Cat
# The artist is: Adele
# The artist is: Justin Bieber
# The artist is: Camila Cabello, Ed Sheeran
# The artist is: Elley Duhé
# The artist is: Cris Mj
# The artist is: Lil Nas X
# The artist is: Lost Frequencies, Calum Scott
# The artist is: Dove Cameron
# The artist is: Ed Sheeran
# The artist is: Jaymes Young
# The artist is: Farruko
# The artist is: Tiësto, Ava Max
# The artist is: Olivia Rodrigo
# The artist is: Coldplay, BTS
# The artist is: The Walters
# The artist is: The Weeknd
# The artist is: Tainy, Bad Bunny, Julieta Venegas
# The artist is: Megan Thee Stallion, Dua Lipa
# ...

# %%
for songs in names_list:
    print("The song is: " + songs)
# Out:
# The song is: Heat Waves
# The song is: STAY (with Justin Bieber)
# The song is: Envolver
# The song is: Enemy (with JID) - from the series Arcane League of Legends
# The song is: abcdefu
# The song is: Cold Heart - PNAU Remix
# The song is: MAMIII
# The song is: INDUSTRY BABY (feat. Jack Harlow)
# The song is: Desesperados
# The song is: Shivers
# The song is: Woman
# The song is: Easy On Me
# The song is: Ghost
# The song is: Bam Bam (feat. Ed Sheeran)
# The song is: MIDDLE OF THE NIGHT
# The song is: Una Noche en Medellín
# The song is: THATS WHAT I WANT
# The song is: Where Are You Now
# The song is: Boyfriend
# The song is: Bad Habits
# The song is: Infinity
# The song is: Pepas
# The song is: The Motto
# The song is: good 4 u
# The song is: My Universe
# The song is: I Love You So
# The song is: Blinding Lights
# The song is: Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)
# The song is: Sweetest Pie
# The song is: Something In The Way
# The song is: Another Love
# ...
