# %%
from dotenv import load_dotenv
import pandas as pd
import csv
import os
import base64
import requests
from requests import post, get
from scipy.stats import linregress
import json
import matplotlib.pyplot as plt
from pprint import pprint
from ids import id
from ids import secret

# %%
load_dotenv()
client_id = id
client_secret = secret

# %%
# Defining functions <3

def get_token():
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization" : "Basic " + auth_base64,
        "Content-Type" : "application/x-www-form-urlencoded"
    }

    data = {"grant_type" : "client_credentials"}

    result = requests.post(url, headers = headers, data = data)
    json_response = json.loads(result.content)
    token = json_response["access_token"]
    return token

def get_auth_header(token):
    return{"Authorization" : "Bearer " + token}

def search_for_playlist(token, playlist_name):
    url = "https://api.spotify.com/v1/search"
    headers = get_auth_header(token)
    query = f"?q={playlist_name}&type=playlist&limit=1"
    query_url = url + query
    result = requests.get(query_url, headers = headers)
    json_result_playlist = json.loads(result.content)["playlists"]["items"]
    if len(json_result_playlist) == 0:
        print("No playlist with this name found...")
        return None
    
    # pprint(json_result_playlist)
    return json_result_playlist[0]

def get_songs_in_playlist(token, artist_id):
    url = f"https://api.spotify.com/v1/playlists/{playlist_id}"
    headers = get_auth_header(token)
    result = requests.get(url, headers = headers)
    json_result = json.loads(result.content)["tracks"]["items"]
    # pprint(json_result)
    return json_result

def get_AF_in_songs(token, id_list1):    
    url = f"https://api.spotify.com/v1/audio-features?ids={id_list1}"
    headers = get_auth_header(token)
    response = requests.get(url, headers = headers)
    response_json = response.json()
    # pprint(response_json)
    return response_json

# %% [markdown]
# # Playlists Data Frames

# %%
# For 2019 playlist
token = get_token()
result = search_for_playlist(token, "Top Canciones 2019")
playlist_id = result["id"]
songs = get_songs_in_playlist(token, playlist_id)
song_list = []
for idx, song in enumerate(songs):
    song_data = {"Song":song["track"]["name"],
                 "Artist":song["track"]["artists"][0]["name"],
                 "Song Lenght (ms)":song["track"]["duration_ms"],
                 "Popularity":song["track"]["popularity"],
                 "Release date":song["track"]["album"]["release_date"],
                 "Song Id":song["track"]["id"]}
    song_list.append(song_data)
spoti_19 = pd.DataFrame(song_list)
# spoti_19.head()

# %%
# For 2020 playlist
token = get_token()
result = search_for_playlist(token, "Top Canciones de 2020")
playlist_id = result["id"]
songs = get_songs_in_playlist(token, playlist_id)
song_list = []
for idx, song in enumerate(songs):
    song_data = {"Song":song["track"]["name"],
                 "Artist":song["track"]["artists"][0]["name"],
                 "Song Lenght (ms)":song["track"]["duration_ms"],
                 "Popularity":song["track"]["popularity"],
                 "Release date":song["track"]["album"]["release_date"],
                 "Song Id":song["track"]["id"]}
    song_list.append(song_data)
spoti_20 = pd.DataFrame(song_list)
# spoti_20.head()

# %%
# For 2021 playlist
token = get_token()
result = search_for_playlist(token, "Top Canciones México 2021")
playlist_id = result["id"]
songs = get_songs_in_playlist(token, playlist_id)
song_list = []
for idx, song in enumerate(songs):
    song_data = {"Song":song["track"]["name"],
                 "Artist":song["track"]["artists"][0]["name"],
                 "Song Lenght (ms)":song["track"]["duration_ms"],
                 "Popularity":song["track"]["popularity"],
                 "Release date":song["track"]["album"]["release_date"],
                 "Song Id":song["track"]["id"]}
    song_list.append(song_data)
spoti_21 = pd.DataFrame(song_list)
# spoti_21.head()

# %%
# For 2022 playlist
token = get_token()
result = search_for_playlist(token, "Top Canciones México 2022")
playlist_id = result["id"]
songs = get_songs_in_playlist(token, playlist_id)
song_list = []
for idx, song in enumerate(songs):
    song_data = {"Song":song["track"]["name"],
                 "Artist":song["track"]["artists"][0]["name"],
                 "Song Lenght (ms)":song["track"]["duration_ms"],
                 "Popularity":song["track"]["popularity"],
                 "Release date":song["track"]["album"]["release_date"],
                 "Song Id":song["track"]["id"]}
    song_list.append(song_data)
spoti_22 = pd.DataFrame(song_list)
# spoti_22.head()

# %%
# Merge the playlists data frames
spoti=spoti_19.merge(spoti_20, how='outer')
spoti=spoti.merge(spoti_21, how='outer')
spoti=spoti.merge(spoti_22, how='outer')
spoti.drop_duplicates
spoti
# Out:
#                             Song                  Artist  Song Lenght (ms)  \
# 0                  Calma - Remix              Pedro Capó            238200
# 1                      Con Calma            Daddy Yankee            193226
# 2                          Te Vi                 Piso 21            231848
# 3                     Otro Trago                    Sech            225933
# 4                       Callaita               Bad Bunny            250533
# ..                           ...                     ...               ...
# 230                    Un Ratito               Bad Bunny            176936
# 231               Si Fuera Fácil  Grupo Marca Registrada            170496
# 232                   Dos Mil 16               Bad Bunny            208615
# 233           Siempre Pendientes              Peso Pluma            186828
# 234  Se Fue La Pantera (En Vivo)             Grupo Firme            202021
#
#      Popularity Release date                 Song Id
# 0            77   2018-10-05  5iwz1NiezX7WWjnCgY5TH4
# 1            83   2019-01-24  5w9c2J52mkdntKOmRLeM2m
# 2            80   2018-12-14  059bcIhyc2SBwm6sw2AZzd
# 3            75   2019-04-19  1Ej96GIBCTvgH7tNX1r3qr
# 4            80   2019-05-31  2TH65lNHgvLxCKXM3apjxI
# ..          ...          ...                     ...
# 230          82   2022-05-06  5CzixCxDkRXX9mScCmah8O
# 231          77   2022-05-27  7Jph6HJbfURt4Fea19IED3
# 232          81   2022-05-06  4d4ZXH4dr5bYfgErHiZCX2
# 233          85   2022-08-15  3gfSH9aYZbyGjdmbeoWliw
# 234          77   2021-08-12  6Yard5LK4aXEn0kBKtHSob
#
# [235 rows x 6 columns]

# %% [markdown]
# # Song Features

# %%
# Tomar la columna Song Id del DataFrame con los Top Tracks y convertir los valores en una lista de strings separadas por comas, para pasarlo así al request de los Audio Features

id_list = spoti["Song Id"]
id_list1 = id_list[0:100]
id_list1 = ",".join(id_list1)
id_list2= id_list[100:200]
id_list2 = ",".join(id_list2)
id_list3= id_list[200:]
id_list3 = ",".join(id_list3)
# print(id_list1)

# %%
# DataFrame con los Audio Features del 0 al 100

token = get_token()
audio_features_data = get_AF_in_songs(token, id_list1)["audio_features"]
# pprint(audio_features_data)
audio_features_list = []


for idx, af in enumerate(audio_features_data):
    audio_features = {"Acousticness":af["acousticness"],
                 "Danceability":af["danceability"],
                 "Energy":af["energy"],
                 "Instrumentalness":af["energy"],
                 "Liveness":af["energy"],
                 "Speechiness":af["speechiness"],
                 "Tempo":af["tempo"],
                 "Key" : af["key"],
                 "Loudness" : af["loudness"],
                 "Mode" : af["mode"],
                 "Time Signature" : af["time_signature"],
                 "Valence":af["valence"],
                 "Song Id":af["id"]}
    audio_features_list.append(audio_features)
audio_features_df1 = pd.DataFrame(audio_features_list)
audio_features_df1
# Out:
#     Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0         0.3230         0.826   0.773             0.773     0.773
# 1         0.1100         0.737   0.860             0.860     0.860
# 2         0.0446         0.877   0.777             0.777     0.777
# 3         0.1360         0.746   0.700             0.700     0.700
# 4         0.6000         0.610   0.624             0.624     0.624
# ..           ...           ...     ...               ...       ...
# 95        0.0427         0.842   0.734             0.734     0.734
# 96        0.1330         0.806   0.778             0.778     0.778
# 97        0.1900         0.770   0.750             0.750     0.750
# 98        0.1880         0.857   0.772             0.772     0.772
# 99        0.0196         0.864   0.590             0.590     0.590
#
#     Speechiness    Tempo  Key  Loudness  Mode  Time Signature  Valence  \
# 0        0.0524  126.899   11    -4.218     0               4    0.761
# 1        0.0593   93.989    8    -2.652     0               4    0.656
# 2        0.1170  102.020    1    -4.246     1               4    0.706
# 3        0.3410  176.044    0    -4.669     1               4    0.619
# 4        0.3090  176.169    2    -4.773     1               4    0.244
# ..          ...      ...  ...       ...   ...             ...      ...
# 95       0.0588  137.958    1    -5.065     0               4    0.952
# 96       0.0616   95.993    1    -4.577     0               4    0.840
# 97       0.0785   99.997    0    -2.715     1               4    0.609
# 98       0.1950   94.030   10    -4.737     0               4    0.589
# 99       0.4990  161.989    1    -8.768     1               4    0.579
#
#                    Song Id
# 0   5iwz1NiezX7WWjnCgY5TH4
# 1   5w9c2J52mkdntKOmRLeM2m
# 2   059bcIhyc2SBwm6sw2AZzd
# 3   1Ej96GIBCTvgH7tNX1r3qr
# 4   2TH65lNHgvLxCKXM3apjxI
# ..                     ...
# 95  22vgEDb5hykfaTwLuskFGD
# 96  71iAechwVKGu26pahzFL0k
# 97  08aYFNUTIOMGq93e2VSArQ
# 98  28O1p0bQXH2F6Qn8jBZZR4
# 99  78M7CiqTpJYoPQKkwjM48Z
#
# [100 rows x 13 columns]

# %%
# DataFrame con los Audio Features del 101 al 200

token = get_token()
audio_features_data = get_AF_in_songs(token, id_list2)["audio_features"]
# pprint(audio_features_data)
audio_features_list = []


for idx, af in enumerate(audio_features_data):
    audio_features = {"Acousticness":af["acousticness"],
                 "Danceability":af["danceability"],
                 "Energy":af["energy"],
                 "Instrumentalness":af["energy"],
                 "Liveness":af["energy"],
                 "Speechiness":af["speechiness"],
                 "Tempo":af["tempo"],
                 "Key" : af["key"],
                 "Loudness" : af["loudness"],
                 "Mode" : af["mode"],
                 "Time Signature" : af["time_signature"],
                 "Valence":af["valence"],
                 "Song Id":af["id"]}
    audio_features_list.append(audio_features)
audio_features_df2 = pd.DataFrame(audio_features_list)
audio_features_df2
# Out:
#     Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0        0.29500         0.803   0.715             0.715     0.715
# 1        0.00146         0.514   0.730             0.730     0.730
# 2        0.01030         0.607   0.829             0.829     0.829
# 3        0.18500         0.783   0.727             0.727     0.727
# 4        0.11000         0.883   0.668             0.668     0.668
# ..           ...           ...     ...               ...       ...
# 95       0.09930         0.650   0.715             0.715     0.715
# 96       0.08000         0.647   0.686             0.686     0.686
# 97       0.14100         0.801   0.475             0.475     0.475
# 98       0.01250         0.621   0.782             0.782     0.782
# 99       0.65600         0.870   0.516             0.516     0.516
#
#     Speechiness    Tempo  Key  Loudness  Mode  Time Signature  Valence  \
# 0        0.2980  101.085    2    -3.280     1               4    0.574
# 1        0.0598  171.005    1    -5.934     1               4    0.334
# 2        0.3790   96.172    2    -4.074     1               4    0.685
# 3        0.3890  180.067    6    -3.454     0               4    0.558
# 4        0.1130   87.972    9    -2.957     1               4    0.676
# ..          ...      ...  ...       ...   ...             ...      ...
# 95       0.2530  106.672    5    -5.198     0               4    0.187
# 96       0.0413   79.928    3    -5.745     0               4    0.268
# 97       0.0516   98.047    7    -8.797     0               4    0.234
# 98       0.0440  128.033    2    -5.548     1               4    0.550
# 99       0.0541  111.005    1    -8.006     1               4    0.530
#
#                    Song Id
# 0   7k4t7uLgtOxPwTpFmtJNTY
# 1   0VjIjW4GlUZAMYd2vXMi3b
# 2   2DEZmgHKAvm41k4J3R2E9Y
# 3   1yoMvmasuxZfqHEipJhRbp
# 4   7sQKy5vlPQllr0k9IjYJv3
# ..                     ...
# 95  1IHWl5LamUGEuP4ozKQSXZ
# 96  3k3NWokhRRkEPhCzPmV8TW
# 97  5Eax0qFko2dh7Rl2lYs3bx
# 98  2tTmW7RDtMQtBk7m2rYeSw
# 99  7dSZ6zGTQx66c2GF91xCrb
#
# [100 rows x 13 columns]

# %%
# DataFrame con los Audio Features del 201 al 235

token = get_token()
audio_features_data = get_AF_in_songs(token, id_list3)["audio_features"]
# pprint(audio_features_data)
audio_features_list = []


for idx, af in enumerate(audio_features_data):
    audio_features = {"Acousticness":af["acousticness"],
                 "Danceability":af["danceability"],
                 "Energy":af["energy"],
                 "Instrumentalness":af["energy"],
                 "Liveness":af["energy"],
                 "Speechiness":af["speechiness"],
                 "Tempo":af["tempo"],
                 "Key" : af["key"],
                 "Loudness" : af["loudness"],
                 "Mode" : af["mode"],
                 "Time Signature" : af["time_signature"],
                 "Valence":af["valence"],
                 "Song Id":af["id"]}
    audio_features_list.append(audio_features)
audio_features_df3 = pd.DataFrame(audio_features_list)
audio_features_df3
# Out:
#     Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0         0.2940         0.804   0.674             0.674     0.674
# 1         0.0151         0.829   0.799             0.799     0.799
# 2         0.3950         0.551   0.436             0.436     0.436
# 3         0.0889         0.639   0.703             0.703     0.703
# 4         0.3560         0.869   0.694             0.694     0.694
# 5         0.3420         0.520   0.731             0.731     0.731
# 6         0.0706         0.876   0.498             0.498     0.498
# 7         0.4370         0.588   0.452             0.452     0.452
# 8         0.5500         0.702   0.586             0.586     0.586
# 9         0.0924         0.870   0.548             0.548     0.548
# 10        0.0877         0.784   0.737             0.737     0.737
# 11        0.0845         0.836   0.703             0.703     0.703
# 12        0.5830         0.835   0.679             0.679     0.679
# 13        0.3200         0.453   0.673             0.673     0.673
# 14        0.2340         0.695   0.636             0.636     0.636
# 15        0.0225         0.795   0.684             0.684     0.684
# 16        0.8600         0.577   0.363             0.363     0.363
# 17        0.1220         0.748   0.761             0.761     0.761
# 18        0.3660         0.743   0.890             0.890     0.890
# 19        0.2290         0.663   0.786             0.786     0.786
# 20        0.0620         0.746   0.844             0.844     0.844
# 21        0.0575         0.796   0.680             0.680     0.680
# 22        0.7620         0.797   0.616             0.616     0.616
# 23        0.3800         0.690   0.662             0.662     0.662
# 24        0.3560         0.564   0.903             0.903     0.903
# 25        0.4660         0.696   0.623             0.623     0.623
# 26        0.4630         0.436   0.400             0.400     0.400
# 27        0.2070         0.839   0.690             0.690     0.690
# 28        0.2830         0.794   0.594             0.594     0.594
# 29        0.1210         0.594   0.527             0.527     0.527
# 30        0.3050         0.787   0.546             0.546     0.546
# 31        0.4460         0.794   0.677             0.677     0.677
# 32        0.1230         0.817   0.670             0.670     0.670
# 33        0.3310         0.774   0.748             0.748     0.748
# 34        0.1180         0.557   0.660             0.660     0.660
#
#     Speechiness    Tempo  Key  Loudness  Mode  Time Signature  Valence  \
# 0        0.0333   99.968    5    -5.453     0               4    0.292
# 1        0.0897   97.013    9    -5.389     1               4    0.471
# 2        0.0428  188.651    8    -8.029     1               3    0.862
# 3        0.0794  169.888    4    -6.330     0               4    0.138
# 4        0.0783   90.020    1    -3.350     0               4    0.511
# 5        0.0557  173.930    6    -5.338     0               4    0.662
# 6        0.0478  122.016   10    -7.511     1               4    0.428
# 7        0.0268  139.953    7    -4.750     1               4    0.734
# 8        0.1180  112.852    8    -5.317     1               4    0.965
# 9        0.0770   96.018   10    -5.253     0               4    0.832
# 10       0.0758   97.500    5    -2.174     1               3    0.623
# 11       0.0657   94.048    4    -3.554     0               4    0.902
# 12       0.0364  124.980    7    -5.329     0               4    0.850
# 13       0.1440   92.060    8    -5.649     1               4    0.266
# 14       0.3170  174.140    5    -4.654     1               4    0.575
# 15       0.0419  114.011   11    -3.971     0               4    0.419
# 16       0.0263   91.511    7   -12.378     1               4    0.265
# 17       0.1020  116.041    2    -6.621     1               4    0.362
# 18       0.0837  107.635    7    -5.451     0               4    0.809
# 19       0.1950  196.120   11    -3.510     0               4    0.579
# 20       0.0359  123.014   11    -3.499     0               4    0.934
# 21       0.3700  179.923   10    -5.555     0               4    0.710
# 22       0.3750  103.071    1   -10.229     0               4    0.451
# 23       0.0430  143.096    2    -4.537     1               3    0.488
# 24       0.3070   78.293    5    -3.221     1               4    0.607
# 25       0.0438  154.028    6    -8.738     0               3    0.965
# 26       0.1100   75.576    0    -6.521     1               3    0.568
# 27       0.0615  151.991   11    -4.464     1               4    0.744
# 28       0.1390   99.238    7    -8.698     0               3    0.637
# 29       0.0335  172.712    0    -9.335     1               4    0.692
# 30       0.0532   93.050    0    -7.094     0               4    0.222
# 31       0.0713  101.467   10    -9.969     1               3    0.611
# 32       0.0506  130.058    1    -6.534     1               3    0.495
# 33       0.0352  135.929    0    -7.086     1               3    0.714
# 34       0.0768  128.179    3    -4.467     1               4    0.907
#
#                    Song Id
# 0   6Xom58OOXk2SoU711L2IXO
# 1   4tYFy8ALRjIZvnvSLw5lxN
# 2   74WROFXsox6wkeUrEK2DS6
# 3   4gzsuuZypVbxs0Af1LSZyB
# 4   6mmPpaltUZK7xjNlBPQQ0p
# 5   4Dvkj6JhhA12EX05fT7y2e
# 6   31i56LZnwE6uSu3exoHjtB
# 7   0UXlu64mDLvfzR8IXMz06J
# 8   5kpxVMDvYGRmNqawPqDTYR
# 9   1O2pcBJGej0pmH2Y9XZMs6
# 10  3ZGkdrigbWXLgHungXfZkt
# 11  7FlQk2gJ6TBrHHiidvdR2O
# 12  5ww2BF9slyYgNOk37BlC4u
# 13  1UdzJEpgJxtuXAlCOvD4S0
# 14  2rurDawMfoKP4uHyb2kJBt
# 15  41oY4WCTj5kccfesTVFnvN
# 16  75UMtPC77vqKRwfSuYuNPO
# 17  5TMLavqGRKNxgzMBrVpC9R
# 18  5IdyvWCaUa7AgTxMsFj0wB
# 19  1797zYiX4cKosMH836X9Gt
# 20  6ylDpki1VpIsc525KC1ojF
# 21  6y8z28epOv5FlaxDv1Lo5B
# 22  44XjoNvtwevktFKjvVe1vH
# 23  6YNTL320OEMAg4ORqGYt1v
# 24  1dm6z1fWB0cErMszU25dy2
# 25  2NWaWZZLFMcr5P4uI2KvWy
# 26  6HIIuuUIEzH1meVdGbMXyf
# 27  6VrQTLzzuyGIYjUDe4kAZk
# 28  4w273WCBXwM4P3jTX5HkB2
# 29  23Lyy7ZXRvzfgH4JtDkKrX
# 30  5CzixCxDkRXX9mScCmah8O
# 31  7Jph6HJbfURt4Fea19IED3
# 32  4d4ZXH4dr5bYfgErHiZCX2
# 33  3gfSH9aYZbyGjdmbeoWliw
# 34  6Yard5LK4aXEn0kBKtHSob

# %% [markdown]
# # Merge and export

# %%
total_af = audio_features_df1.merge(audio_features_df2, how='outer')
total_af = total_af.merge(audio_features_df3, how='outer')
total_af
# Out:
#      Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0          0.3230         0.826   0.773             0.773     0.773
# 1          0.1100         0.737   0.860             0.860     0.860
# 2          0.0446         0.877   0.777             0.777     0.777
# 3          0.1360         0.746   0.700             0.700     0.700
# 4          0.6000         0.610   0.624             0.624     0.624
# ..            ...           ...     ...               ...       ...
# 230        0.3050         0.787   0.546             0.546     0.546
# 231        0.4460         0.794   0.677             0.677     0.677
# 232        0.1230         0.817   0.670             0.670     0.670
# 233        0.3310         0.774   0.748             0.748     0.748
# 234        0.1180         0.557   0.660             0.660     0.660
#
#      Speechiness    Tempo  Key  Loudness  Mode  Time Signature  Valence  \
# 0         0.0524  126.899   11    -4.218     0               4    0.761
# 1         0.0593   93.989    8    -2.652     0               4    0.656
# 2         0.1170  102.020    1    -4.246     1               4    0.706
# 3         0.3410  176.044    0    -4.669     1               4    0.619
# 4         0.3090  176.169    2    -4.773     1               4    0.244
# ..           ...      ...  ...       ...   ...             ...      ...
# 230       0.0532   93.050    0    -7.094     0               4    0.222
# 231       0.0713  101.467   10    -9.969     1               3    0.611
# 232       0.0506  130.058    1    -6.534     1               3    0.495
# 233       0.0352  135.929    0    -7.086     1               3    0.714
# 234       0.0768  128.179    3    -4.467     1               4    0.907
#
#                     Song Id
# 0    5iwz1NiezX7WWjnCgY5TH4
# 1    5w9c2J52mkdntKOmRLeM2m
# 2    059bcIhyc2SBwm6sw2AZzd
# 3    1Ej96GIBCTvgH7tNX1r3qr
# 4    2TH65lNHgvLxCKXM3apjxI
# ..                      ...
# 230  5CzixCxDkRXX9mScCmah8O
# 231  7Jph6HJbfURt4Fea19IED3
# 232  4d4ZXH4dr5bYfgErHiZCX2
# 233  3gfSH9aYZbyGjdmbeoWliw
# 234  6Yard5LK4aXEn0kBKtHSob
#
# [235 rows x 13 columns]

# %%
final_spoti_df = spoti.merge(total_af, on="Song Id", how="outer")
final_spoti_df
# Out:
#                             Song                  Artist  Song Lenght (ms)  \
# 0                  Calma - Remix              Pedro Capó            238200
# 1                      Con Calma            Daddy Yankee            193226
# 2                          Te Vi                 Piso 21            231848
# 3                     Otro Trago                    Sech            225933
# 4                       Callaita               Bad Bunny            250533
# ..                           ...                     ...               ...
# 230                    Un Ratito               Bad Bunny            176936
# 231               Si Fuera Fácil  Grupo Marca Registrada            170496
# 232                   Dos Mil 16               Bad Bunny            208615
# 233           Siempre Pendientes              Peso Pluma            186828
# 234  Se Fue La Pantera (En Vivo)             Grupo Firme            202021
#
#      Popularity Release date                 Song Id  Acousticness  \
# 0            77   2018-10-05  5iwz1NiezX7WWjnCgY5TH4        0.3230
# 1            83   2019-01-24  5w9c2J52mkdntKOmRLeM2m        0.1100
# 2            80   2018-12-14  059bcIhyc2SBwm6sw2AZzd        0.0446
# 3            75   2019-04-19  1Ej96GIBCTvgH7tNX1r3qr        0.1360
# 4            80   2019-05-31  2TH65lNHgvLxCKXM3apjxI        0.6000
# ..          ...          ...                     ...           ...
# 230          82   2022-05-06  5CzixCxDkRXX9mScCmah8O        0.3050
# 231          77   2022-05-27  7Jph6HJbfURt4Fea19IED3        0.4460
# 232          81   2022-05-06  4d4ZXH4dr5bYfgErHiZCX2        0.1230
# 233          85   2022-08-15  3gfSH9aYZbyGjdmbeoWliw        0.3310
# 234          77   2021-08-12  6Yard5LK4aXEn0kBKtHSob        0.1180
#
#      Danceability  Energy  Instrumentalness  Liveness  Speechiness    Tempo  \
# 0           0.826   0.773             0.773     0.773       0.0524  126.899
# 1           0.737   0.860             0.860     0.860       0.0593   93.989
# 2           0.877   0.777             0.777     0.777       0.1170  102.020
# 3           0.746   0.700             0.700     0.700       0.3410  176.044
# 4           0.610   0.624             0.624     0.624       0.3090  176.169
# ..            ...     ...               ...       ...          ...      ...
# 230         0.787   0.546             0.546     0.546       0.0532   93.050
# 231         0.794   0.677             0.677     0.677       0.0713  101.467
# 232         0.817   0.670             0.670     0.670       0.0506  130.058
# 233         0.774   0.748             0.748     0.748       0.0352  135.929
# 234         0.557   0.660             0.660     0.660       0.0768  128.179
#
#      Key  Loudness  Mode  Time Signature  Valence
# 0     11    -4.218     0               4    0.761
# 1      8    -2.652     0               4    0.656
# 2      1    -4.246     1               4    0.706
# 3      0    -4.669     1               4    0.619
# 4      2    -4.773     1               4    0.244
# ..   ...       ...   ...             ...      ...
# 230    0    -7.094     0               4    0.222
# 231   10    -9.969     1               3    0.611
# 232    1    -6.534     1               3    0.495
# 233    0    -7.086     1               3    0.714
# 234    3    -4.467     1               4    0.907
#
# [235 rows x 18 columns]

# %%
# final_spoti_df to a csv file

final_spoti_df.to_csv('outputs/spotify_and_features.csv', index=False)
